# %% [markdown]
# # DataFrames III: Data Extraction

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset is a collection of all James Bond movies.

# %%
bond = pd.read_csv('jamesbond.csv')
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# ## The set_index and reset_index Methods
# - The index serves as the collection of primary identifiers/labels/entrypoints for the rows.
# - The fastest way to extract a row is from a sorted index by position/label.
# - Pandas uses index labels/values when merging different objects together.
# - The `set_index` method sets an existing column as the index of the **DataFrame**.
# - The `reset_index` method sets the standard ascending numeric index as the index of the **DataFrame**.

# %% [markdown]
# Indicando la columna que se desea utilizar como índice desde la importación de los datos

# %%
bond = pd.read_csv('jamesbond.csv', index_col='Film')
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond = pd.read_csv('jamesbond.csv')
bond.head()

bond.set_index('Film') # Esto no modifica el DataFrame original, solo es una vista temporal
bond = bond.set_index('Film') # Esto modifica el DataFrame original
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond = bond.reset_index() # Esto no modifica el DataFrame original, solo es una vista temporal con los índices originales
bond
bond = bond.set_index('Film') # Esto modifica el DataFrame original
bond
bond.reset_index(drop=True).head() # Esto modifica el DataFrame original eliminando la columna de índices anterior
# Out:
#    Year         Actor       Director  Box Office  Budget  Bond Actor Salary
# 0  1962  Sean Connery  Terence Young       448.8     7.0                0.6
# 1  1963  Sean Connery  Terence Young       543.8    12.6                1.6
# 2  1964  Sean Connery   Guy Hamilton       820.4    18.6                3.2
# 3  1965  Sean Connery  Terence Young       848.1    41.9                4.7
# 4  1967   David Niven     Ken Hughes       315.0    85.0                NaN

# %%
bond = pd.read_csv('jamesbond.csv')
bond.head()
bond = bond.set_index('Film') # Esto modifica el DataFrame original

# Al hacer esto, la columna Year se convierte en el índice y se elimina del DataFrame, porque Film era el índice anterior
bond = bond.set_index("Year")
bond.head()
# Out:
#              Actor       Director  Box Office  Budget  Bond Actor Salary
# Year
# 1962  Sean Connery  Terence Young       448.8     7.0                0.6
# 1963  Sean Connery  Terence Young       543.8    12.6                1.6
# 1964  Sean Connery   Guy Hamilton       820.4    18.6                3.2
# 1965  Sean Connery  Terence Young       848.1    41.9                4.7
# 1967   David Niven     Ken Hughes       315.0    85.0                NaN

# %%
bond = pd.read_csv('jamesbond.csv')
bond.head()
# Por eso, si queremos mantener los indices anteriores, debemos hacer un reset_index antes de hacer el set_index
bond = bond.set_index('Film') # Esto modifica el DataFrame original

# Aplica primero el reset_index para no perder los índices anteriores
bond = bond.reset_index().set_index("Year")
bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %% [markdown]
# ## Retrieve Rows by Index Position with iloc Accessor
# - The `iloc` accessor retrieves one or more rows by index position.
# - Provide a pair of square brackets after the accessor.
# - `iloc` accepts single values, lists, and slices.

# %%
bond = pd.read_csv('jamesbond.csv')
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.iloc[5]
bond.iloc[[15, 20]]
bond.iloc[4:8]
bond.iloc[0:6]
bond.iloc[:6]

bond.iloc[20:]
# Out:
#                        Film  Year           Actor            Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig     Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                  Skyfall  2012    Daniel Craig          Sam Mendes
# 25                  Spectre  2015    Daniel Craig          Sam Mendes
# 26           No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %% [markdown]
# ## Retrieve Rows by Index Label with loc Accessor
# - The `loc` accessor retrieves one or more rows by index label.
# - Provide a pair of square brackets after the accessor.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.loc["Goldfinger"]
bond.loc["GoldenEye"]
bond.loc["Casino Royale"]
# bond.loc["Sacred Bond"]

bond.loc[["Octopussy", "Moonraker"]]
bond.loc[["Moonraker", "Octopussy"]]
bond.loc[["Moonraker", "Octopussy", "Casino Royale"]]
# bond.loc[["Moonraker", "Octopussy", "Casino Royale", "Gold Bond"]]

bond.loc["Diamonds Are Forever":"Moonraker"]
bond.loc["Moonraker":"Diamonds Are Forever"]

bond.loc["GoldenEye":]
bond.loc[:"On Her Majesty's Secret Service"]

# bond.loc[:"Casino Royale"]
# bond.loc["Casino Royale":]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %% [markdown]
# ## Second Arguments to loc and iloc Accessors
# - The second value inside the square brackets targets the columns.
# - The `iloc` requires numeric positions for rows and columns.
# - The `loc` requires labels for rows and columns.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Diamonds Are Forever", "Director"]
bond.loc[["Octopussy", "GoldenEye"], "Director"]
bond.loc[["Octopussy", "GoldenEye"], "Director":"Budget"]
bond.loc["GoldenEye":"Octopussy", "Director":"Budget"]
bond.loc["GoldenEye":"Octopussy", ["Actor", "Bond Actor Salary", "Year"]]
# Out:
#                                 Actor  Bond Actor Salary  Year
# Film
# GoldenEye              Pierce Brosnan                5.1  1995
# Goldfinger               Sean Connery                3.2  1964
# Licence to Kill        Timothy Dalton                7.9  1989
# Live and Let Die          Roger Moore                NaN  1973
# Moonraker                 Roger Moore                NaN  1979
# Never Say Never Again    Sean Connery                NaN  1983
# No Time to Die           Daniel Craig               25.0  2021
# Octopussy                 Roger Moore                7.8  1983

# %%
bond.iloc[0, 2]

bond.iloc[3, 5]

bond.iloc[[0, 2], 3]
bond.iloc[[0, 2], [3, 5]]

bond.iloc[:7, :3]
# Out:
#                       Year           Actor         Director
# Film
# A View to a Kill      1985     Roger Moore        John Glen
# Casino Royale         2006    Daniel Craig  Martin Campbell
# Casino Royale         1967     David Niven       Ken Hughes
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori
# Dr. No                1962    Sean Connery    Terence Young
# For Your Eyes Only    1981     Roger Moore        John Glen

# %% [markdown]
# ## Overwrite Value in a DataFrame
# - Use the `iloc` or `loc` accessor on the **DataFrame** to target a value, then provide the equal sign and a new value.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Diamonds Are Forever", "Actor"] = "Sir Sean Connery"

# %%
bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962      Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963      Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964      Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973       Roger Moore        Guy Hamilton
# Moonraker                        1979       Roger Moore       Lewis Gilbert
# Never Say Never Again            1983      Sean Connery      Irvin Kershner
# No Time to Die                   2021      Daniel Craig  Cary Joji Fukunaga
# Octopussy                        1983       Roger Moore           John Glen
# On Her Majesty's Secret Service  1969    George Lazenby       Peter R. Hunt
# Quantum of Solace                2008      Daniel Craig        Marc Forster
# Skyfall                          2012      Daniel Craig          Sam Mendes
# Spectre                          2015      Daniel Craig          Sam Mendes
# The Living Daylights             1987    Timothy Dalton           John Glen
# The Man with the Golden Gun      1974       Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977       Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999    Pierce Brosnan       Michael Apted
# Thunderball                      1965      Sean Connery       Terence Young
# Tomorrow Never Dies              1997    Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967      Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# No Time to Die                        774.2   301.0               25.0
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3               30.0
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %% [markdown]
# ##  Overwrite Multiple Values in a DataFrame
# - The `replace` method replaces all occurrences of a **Series** value with another value (think of it like "Find and Replace").
# - To overwrite multiple values in a **DataFrame**, remember to use an accessor on the **DataFrame** itself.
# - Accessors like `loc` and `iloc` can accept Boolean Series. Use them to target the values to overwrite.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond["Actor"] = bond["Actor"].replace("Sean Connery", "Sir Sean Connery")
bond.head()
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond[bond["Actor"] == "Sean Connery"].loc[:, "Actor"] = "Sir Sean Connery" # Esto no modifica el DataFrame original

# %%
is_sean_connery = bond["Actor"] == "Sean Connery" # Esto crea una Serie de booleanos
bond.loc[is_sean_connery, "Actor"] = "Sir Sean Connery" # Esto modifica el DataFrame original con los valores que cumplen la condición

# %%
bond.head()
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# ## Rename Index Labels or Columns in a DataFrame
# - The `rename` method accepts a dictionary for either its `columns` or `index` parameters.
# - The dictionary keys represent the existing names and the values represent the new names.
# - We can replace all columns by overwriting the **DataFrame's** `columns` attribute.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond = bond.rename(columns={"Year": "Release Date", "Box Office": "Revenue"})
bond.head()
# Out:
#                       Release Date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
swap = {
    "GoldenEye": "Golden Eye",
    "The World Is Not Enough": "Best Bond Movie Ever",
    "Dr. No": "Dr No"
}

bond.rename(index=swap)
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr No                                    1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# Golden Eye                               1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# No Time to Die                           2021    Daniel Craig
# Octopussy                                1983     Roger Moore
# On Her Majesty's Secret Service          1969  George Lazenby
# Quantum of Solace                        2008    Daniel Craig
# Skyfall                                  2012    Daniel Craig
# Spectre                                  2015    Daniel Craig
# The Living Daylights                     1987  Timothy Dalton
# The Man with the Golden Gun              1974     Roger Moore
# The Spy Who Loved Me                     1977     Roger Moore
# Best Bond Movie Ever                     1999  Pierce Brosnan
# Thunderball                              1965    Sean Connery
# Tomorrow Never Dies                      1997  Pierce Brosnan
# You Only Live Twice                      1967    Sean Connery
#
#                                            Director  Revenue  Budget  \
# Film
# A View to a Kill                          John Glen    275.2    54.5
# Casino Royale                       Martin Campbell    581.5   145.3
# Casino Royale                            Ken Hughes    315.0    85.0
# Diamonds Are Forever                   Guy Hamilton    442.5    34.7
# Die Another Day                        Lee Tamahori    465.4   154.2
# Dr No                                 Terence Young    448.8     7.0
# For Your Eyes Only                        John Glen    449.4    60.2
# From Russia with Love                 Terence Young    543.8    12.6
# Golden Eye                          Martin Campbell    518.5    76.9
# Goldfinger                             Guy Hamilton    820.4    18.6
# Licence to Kill                           John Glen    250.9    56.7
# Live and Let Die                       Guy Hamilton    460.3    30.8
# Moonraker                             Lewis Gilbert    535.0    91.5
# Never Say Never Again                Irvin Kershner    380.0    86.0
# No Time to Die                   Cary Joji Fukunaga    774.2   301.0
# Octopussy                                 John Glen    373.8    53.9
# On Her Majesty's Secret Service       Peter R. Hunt    291.5    37.3
# Quantum of Solace                      Marc Forster    514.2   181.4
# Skyfall                                  Sam Mendes    943.5   170.2
# Spectre                                  Sam Mendes    726.7   206.3
# The Living Daylights                      John Glen    313.5    68.8
# The Man with the Golden Gun            Guy Hamilton    334.0    27.7
# The Spy Who Loved Me                  Lewis Gilbert    533.0    45.1
# Best Bond Movie Ever                  Michael Apted    439.5   158.3
# Thunderball                           Terence Young    848.1    41.9
# Tomorrow Never Dies              Roger Spottiswoode    463.2   133.9
# You Only Live Twice                   Lewis Gilbert    514.2    59.9
#
#                                  Bond Actor Salary
# Film
# A View to a Kill                               9.1
# Casino Royale                                  3.3
# Casino Royale                                  NaN
# Diamonds Are Forever                           5.8
# Die Another Day                               17.9
# Dr No                                          0.6
# For Your Eyes Only                             NaN
# From Russia with Love                          1.6
# Golden Eye                                     5.1
# Goldfinger                                     3.2
# Licence to Kill                                7.9
# Live and Let Die                               NaN
# Moonraker                                      NaN
# Never Say Never Again                          NaN
# No Time to Die                                25.0
# Octopussy                                      7.8
# On Her Majesty's Secret Service                0.6
# Quantum of Solace                              8.1
# Skyfall                                       14.5
# Spectre                                       30.0
# The Living Daylights                           5.2
# The Man with the Golden Gun                    NaN
# The Spy Who Loved Me                           NaN
# Best Bond Movie Ever                          13.5
# Thunderball                                    4.7
# Tomorrow Never Dies                           10.0
# You Only Live Twice                            4.4

# %%
bond.columns = ["Year of Release", "Actor", "Director", "Gross", "Cost", "Salary"] # Esto cambia los nombres de las columnas y no funciona si no se especifican todas las columnas
bond.head()
# Out:
#                       Year of Release           Actor         Director  Gross  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen  275.2
# Casino Royale                    2006    Daniel Craig  Martin Campbell  581.5
# Casino Royale                    1967     David Niven       Ken Hughes  315.0
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton  442.5
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori  465.4
#
#                        Cost  Salary
# Film
# A View to a Kill       54.5     9.1
# Casino Royale         145.3     3.3
# Casino Royale          85.0     NaN
# Diamonds Are Forever   34.7     5.8
# Die Another Day       154.2    17.9

# %% [markdown]
# ## Delete Rows or Columns from a DataFrame
# - The `drop` method deletes one or more rows/columns from a **DataFrame**.
# - Pass the `index` or `columns` parameters a list of the column names to remove.
# - The `pop` method removes and returns a single **Series** (it mutates the **DataFrame** in the process).
# - Python's `del` keyword also removes a single **Series**.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# Drop no elimina la columna, solo la elimina de la vista del DataFrame, es una copia del DataFrame original

# %%
bond.drop(columns=["Box Office", "Bond Actor Salary", "Actor"])
bond.drop(index=["A View to a Kill", "Casino Royale", "From Russia with Love"])
# Out:
#                                  Year           Actor            Director  \
# Film
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# No Time to Die                   2021    Daniel Craig  Cary Joji Fukunaga
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# No Time to Die                        774.2   301.0               25.0
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3               30.0
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %% [markdown]
# El método pop elimina la columna del DataFrame y la devuelve

# %%
actor = bond.pop("Actor")
actor.head()
# Out:
# Film
# A View to a Kill           Roger Moore
# Casino Royale             Daniel Craig
# Casino Royale              David Niven
# Diamonds Are Forever      Sean Connery
# Die Another Day         Pierce Brosnan
# Name: Actor, dtype: object

# %%
bond.head()
# Out:
#                       Year         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985        John Glen       275.2    54.5
# Casino Royale         2006  Martin Campbell       581.5   145.3
# Casino Royale         1967       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971     Guy Hamilton       442.5    34.7
# Die Another Day       2002     Lee Tamahori       465.4   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %% [markdown]
# El método del elimina la columna del DataFrame pero no la devuelve

# %%
del bond["Director"]
bond
# Out:
#                                  Year  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                 1985       275.2    54.5                9.1
# Casino Royale                    2006       581.5   145.3                3.3
# Casino Royale                    1967       315.0    85.0                NaN
# Diamonds Are Forever             1971       442.5    34.7                5.8
# Die Another Day                  2002       465.4   154.2               17.9
# Dr. No                           1962       448.8     7.0                0.6
# For Your Eyes Only               1981       449.4    60.2                NaN
# From Russia with Love            1963       543.8    12.6                1.6
# GoldenEye                        1995       518.5    76.9                5.1
# Goldfinger                       1964       820.4    18.6                3.2
# Licence to Kill                  1989       250.9    56.7                7.9
# Live and Let Die                 1973       460.3    30.8                NaN
# Moonraker                        1979       535.0    91.5                NaN
# Never Say Never Again            1983       380.0    86.0                NaN
# No Time to Die                   2021       774.2   301.0               25.0
# Octopussy                        1983       373.8    53.9                7.8
# On Her Majesty's Secret Service  1969       291.5    37.3                0.6
# Quantum of Solace                2008       514.2   181.4                8.1
# Skyfall                          2012       943.5   170.2               14.5
# Spectre                          2015       726.7   206.3               30.0
# The Living Daylights             1987       313.5    68.8                5.2
# The Man with the Golden Gun      1974       334.0    27.7                NaN
# The Spy Who Loved Me             1977       533.0    45.1                NaN
# The World Is Not Enough          1999       439.5   158.3               13.5
# Thunderball                      1965       848.1    41.9                4.7
# Tomorrow Never Dies              1997       463.2   133.9               10.0
# You Only Live Twice              1967       514.2    59.9                4.4

# %% [markdown]
# ## Create Random Sample with the sample Method
# - The `sample` method returns a specified one or more random rows from the **DataFrame**.
# - Customize the `axis` parameter to extract random columns.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.sample(n=5) # el parametro n es el número de filas a seleccionar
bond.sample(axis="rows", n = 3) # el parametro n es el número de filas a seleccionar
bond.sample(axis="columns", n = 3) # el parametro n es el número de filas a seleccionar
# Out:
#                                  Box Office            Director  \
# Film
# A View to a Kill                      275.2           John Glen
# Casino Royale                         581.5     Martin Campbell
# Casino Royale                         315.0          Ken Hughes
# Diamonds Are Forever                  442.5        Guy Hamilton
# Die Another Day                       465.4        Lee Tamahori
# Dr. No                                448.8       Terence Young
# For Your Eyes Only                    449.4           John Glen
# From Russia with Love                 543.8       Terence Young
# GoldenEye                             518.5     Martin Campbell
# Goldfinger                            820.4        Guy Hamilton
# Licence to Kill                       250.9           John Glen
# Live and Let Die                      460.3        Guy Hamilton
# Moonraker                             535.0       Lewis Gilbert
# Never Say Never Again                 380.0      Irvin Kershner
# No Time to Die                        774.2  Cary Joji Fukunaga
# Octopussy                             373.8           John Glen
# On Her Majesty's Secret Service       291.5       Peter R. Hunt
# Quantum of Solace                     514.2        Marc Forster
# Skyfall                               943.5          Sam Mendes
# Spectre                               726.7          Sam Mendes
# The Living Daylights                  313.5           John Glen
# The Man with the Golden Gun           334.0        Guy Hamilton
# The Spy Who Loved Me                  533.0       Lewis Gilbert
# The World Is Not Enough               439.5       Michael Apted
# Thunderball                           848.1       Terence Young
# Tomorrow Never Dies                   463.2  Roger Spottiswoode
# You Only Live Twice                   514.2       Lewis Gilbert
#
#                                           Actor
# Film
# A View to a Kill                    Roger Moore
# Casino Royale                      Daniel Craig
# Casino Royale                       David Niven
# Diamonds Are Forever               Sean Connery
# Die Another Day                  Pierce Brosnan
# Dr. No                             Sean Connery
# For Your Eyes Only                  Roger Moore
# From Russia with Love              Sean Connery
# GoldenEye                        Pierce Brosnan
# Goldfinger                         Sean Connery
# Licence to Kill                  Timothy Dalton
# Live and Let Die                    Roger Moore
# Moonraker                           Roger Moore
# Never Say Never Again              Sean Connery
# No Time to Die                     Daniel Craig
# Octopussy                           Roger Moore
# On Her Majesty's Secret Service  George Lazenby
# Quantum of Solace                  Daniel Craig
# Skyfall                            Daniel Craig
# Spectre                            Daniel Craig
# The Living Daylights             Timothy Dalton
# The Man with the Golden Gun         Roger Moore
# The Spy Who Loved Me                Roger Moore
# The World Is Not Enough          Pierce Brosnan
# Thunderball                        Sean Connery
# Tomorrow Never Dies              Pierce Brosnan
# You Only Live Twice                Sean Connery

# %% [markdown]
# ## The nsmallest and nlargest Methods
# - The `nlargest` method returns a specified number of rows with the largest values from a given column.
# - The `nsmallest` method returns rows with the smallest values from a given column.
# - The `nlargest` and `nsmallest` methods are more efficient than sorting the entire **DataFrame**.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# Estos métodos solo funcionan con columnas numéricas

# %%
bond.sort_values("Box Office", ascending=False).head()
# Out:
#                 Year         Actor            Director  Box Office  Budget  \
# Film
# Skyfall         2012  Daniel Craig          Sam Mendes       943.5   170.2
# Thunderball     1965  Sean Connery       Terence Young       848.1    41.9
# Goldfinger      1964  Sean Connery        Guy Hamilton       820.4    18.6
# No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2   301.0
# Spectre         2015  Daniel Craig          Sam Mendes       726.7   206.3
#
#                 Bond Actor Salary
# Film
# Skyfall                      14.5
# Thunderball                   4.7
# Goldfinger                    3.2
# No Time to Die               25.0
# Spectre                      30.0

# %%
bond.nlargest(5, columns="Box Office") # Selecciona las 5 filas con los valores más grandes en la columna especificada
bond["Box Office"].nlargest(8) # Selecciona los 8 valores más grandes de la columna especificada
# Out:
# Film
# Skyfall                  943.5
# Thunderball              848.1
# Goldfinger               820.4
# No Time to Die           774.2
# Spectre                  726.7
# Casino Royale            581.5
# From Russia with Love    543.8
# Moonraker                535.0
# Name: Box Office, dtype: float64

# %%
bond.nsmallest(2, columns="Box Office") # Selecciona las 2 filas con los valores más pequeños en la columna especificada
bond["Box Office"].nsmallest(2) # Selecciona los 2 valores más pequeños de la columna especificada
# Out:
# Film
# Licence to Kill     250.9
# A View to a Kill    275.2
# Name: Box Office, dtype: float64

# %% [markdown]
# ## Filtering with the where Method
# - Similar to square brackets or `loc`, the `where` method filters the original `DataFrame` with a Boolean Series.
# - Pandas will populate rows that do **not** match the criteria with `NaN` values.
# - Leaving in the `NaN` values can be advantageous for certain merge and visualization operations.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
condition = bond["Actor"] == "Sean Connery"
bond[condition]
bond.loc[condition]

bond.where(condition)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# Never Say Never Again            1983.0  Sean Connery  Irvin Kershner
# No Time to Die                      NaN           NaN             NaN
# Octopussy                           NaN           NaN             NaN
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Quantum of Solace                   NaN           NaN             NaN
# Skyfall                             NaN           NaN             NaN
# Spectre                             NaN           NaN             NaN
# The Living Daylights                NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# The World Is Not Enough             NaN           NaN             NaN
# Thunderball                      1965.0  Sean Connery   Terence Young
# Tomorrow Never Dies                 NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                 380.0    86.0                NaN
# No Time to Die                          NaN     NaN                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                                 NaN     NaN                NaN
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                   514.2    59.9                4.4

# %% [markdown]
# ## The apply Method with DataFrames
# - The `apply` method invokes a function on every column or every row in the **DataFrame**.
# - Pass the uninvoked function as the first argument to the `apply` method.
# - Pass the `axis` parameter an argument of `"columns"` to invoke the function on every row.
# - Pandas will pass in the row's values as a **Series** object. We can use accessors like `loc` and `iloc` to extract the column's values for that row.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
def rank_mode(row):
    year = row["Year"]
    budget = row["Budget"]
    actor = row["Actor"]
    
    if year >= 1980 and year <= 1990:
        return "Good"
    
    if actor == "Roger Moore":
        return "Bad"
    
    if budget > 100:
        return "Nice"
    
    return "No idea"
    
bond["comments"] = bond.apply(rank_mode, axis="columns")
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# No Time to Die                   2021    Daniel Craig  Cary Joji Fukunaga
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary  \
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# No Time to Die                        774.2   301.0               25.0
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3               30.0
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4
#
#                                 comments
# Film
# A View to a Kill                    Good
# Casino Royale                       Nice
# Casino Royale                    No idea
# Diamonds Are Forever             No idea
# Die Another Day                     Nice
# Dr. No                           No idea
# For Your Eyes Only                  Good
# From Russia with Love            No idea
# GoldenEye                        No idea
# Goldfinger                       No idea
# Licence to Kill                     Good
# Live and Let Die                     Bad
# Moonraker                            Bad
# Never Say Never Again               Good
# No Time to Die                      Nice
# Octopussy                           Good
# On Her Majesty's Secret Service  No idea
# Quantum of Solace                   Nice
# Skyfall                             Nice
# Spectre                             Nice
# The Living Daylights                Good
# The Man with the Golden Gun          Bad
# The Spy Who Loved Me                 Bad
# The World Is Not Enough             Nice
# Thunderball                      No idea
# Tomorrow Never Dies                 Nice
# You Only Live Twice              No idea
